# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # Create sample data
#
# Car loan of $34,690 with a 7.02 interest rate over 60 months

# %%
# Approach 1: Using List (Nested)

carLoans = [[1, 34867.96, 281037, 2730.1, 2653.2, 26392, 18, 38193, 'Toyota Sienna'],
            [2, 39138, 128736, 3713, 2873, 2387,1037,3824, 'Toyota Sienna'],
            [3, 137, 123971, 2624, 1361, 1387184, 2762, 139, 'Toyota Siena']]

colNames = ['Month',
           'Starting_Balane',
           'Repayment',
           'Ineterest Paid',
           'Principal Paid',
           'New Balance',
           'term',
           'interest_rate',
           'car_type']

# %%
df = pd.DataFrame(data=carLoans, columns=colNames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16dfb4c4eb20> in <module>
# ----> 1 df = pd.DataFrame(data=carLoans, columns=colNames)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#    Month  Starting_Balane  Repayment  Ineterest Paid  Principal Paid  \
# 0      1         34867.96     281037          2730.1          2653.2
# 1      2         39138.00     128736          3713.0          2873.0
# 2      3           137.00     123971          2624.0          1361.0
#
#    New Balance  term  interest_rate       car_type
# 0        26392    18          38193  Toyota Sienna
# 1         2387  1037           3824  Toyota Sienna
# 2      1387184  2762            139   Toyota Siena

# %%
df
# Out:
#    Month  Starting_Balane  Repayment  Ineterest Paid  Principal Paid  \
# 0      1         34867.96     281037          2730.1          2653.2
# 1      2         39138.00     128736          3713.0          2873.0
# 2      3           137.00     123971          2624.0          1361.0
#
#    New Balance  term  interest_rate       car_type
# 0        26392    18          38193  Toyota Sienna
# 1         2387  1037           3824  Toyota Sienna
# 2      1387184  2762            139   Toyota Siena

# %%
filename = '/home/omarubaid/Downloads/Ex_Files_Python_for_Data_Vis/Exercise Files/Pandas/data/car_financing.csv'

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# 5        6          32239.97     687.23         188.60          498.63
# 6        7          31741.34     687.23         185.68          501.55
# 7        8          31239.79     687.23         182.75          504.48
# 8        9          30735.31     687.23         179.80          507.43
# 9       10          30227.88     687.23         176.83          510.40
# 10      11          29717.48     687.23         173.84          513.39
# 11      12          29204.09     687.23         170.84          516.39
# ...

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df.head(6)
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
# 5      6          32239.97     687.23         188.60          498.63
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna
# 5     31741.34    60         0.0702  Toyota Sienna

# %%
df.tail()
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate   car_type
# 403      3164.64    60          0.029  VW Golf R
# 404      2376.27    60          0.029  VW Golf R
# 405      1586.00    60          0.029  VW Golf R
# 406       793.82    60          0.029  VW Golf R
# 407        -0.28    60          0.029  VW Golf R

# %%
df.tail(10)
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 398     51           7855.09     796.01          18.98          777.03
# 399     52           7078.06     796.01          17.10          778.91
# 400     53           6299.15     796.01          15.22          780.79
# 401     54           5518.36     796.01          13.33          782.68
# 402     55           4735.68     796.01          11.44          784.57
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate   car_type
# 398      7078.06    60          0.029  VW Golf R
# 399      6299.15    60          0.029  VW Golf R
# ...

# %%
df.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
# Month               408 non-null int64
# Starting Balance    408 non-null float64
# Repayment           408 non-null float64
# Interest Paid       408 non-null float64
# Principal Paid      408 non-null float64
# New Balance         408 non-null float64
# term                408 non-null int64
# interest_rate       408 non-null float64
# car_type            408 non-null object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %% [markdown]
# ###### Sometimes we are interested in subset of the whole data, so we use:
#
# ## Slicing
#
# 1. How to select columns in pandas
# 2. How to use slicing operations in pandas

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %% [markdown]
# ## Select columns using brackets
#
# With square brackets, you can select one or more columns

# %%
# Select one column using double square brackets
df[['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
# Select multiple columns using double square brackets (in the sequence of how you write in the brackets)
df[['car_type', 'term']].head()
# Out:
#         car_type  term
# 0  Toyota Sienna    60
# 1  Toyota Sienna    60
# 2  Toyota Sienna    60
# 3  Toyota Sienna    60
# 4  Toyota Sienna    60

# %%
type(df[['car_type']].head())
# Out:
# pandas.core.frame.DataFrame

# %%
df['car_type'].head()
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# Name: car_type, dtype: object

# %%
df.loc[:, ['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
df.loc[:, 'car_type'].head()
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# Name: car_type, dtype: object

# %%
df.loc[:, ['car_type']].head(10)
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna
# 5  Toyota Sienna
# 6  Toyota Sienna
# 7  Toyota Sienna
# 8  Toyota Sienna
# 9  Toyota Sienna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
# Month               408 non-null int64
# Starting Balance    408 non-null float64
# Repayment           408 non-null float64
# Interest Paid       408 non-null float64
# Principal Paid      408 non-null float64
# New Balance         408 non-null float64
# term                408 non-null int64
# interest_rate       408 non-null float64
# car_type            408 non-null object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB
